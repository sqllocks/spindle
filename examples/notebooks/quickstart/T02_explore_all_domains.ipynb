# %% [markdown]
# # T02: Explore All Domains
#
# ## What You'll Learn
#
# Spindle ships with **12 pre-built business domains**, each containing a complete relational schema with realistic column definitions and foreign-key relationships. In this notebook you will:
#
# 1. **Import** all 13 domain classes
# 2. **Survey** every domain — see its name, description, table count, and relationship count
# 3. **Deep-dive** into one domain's full schema details
# 4. **Generate** two domains side-by-side and compare their output
#
# ## Prerequisites
#
# - Completed **T01: Hello, Spindle!** (or at least have `sqllocks-spindle` installed)
#
# ## Time Estimate
#
# **~10 minutes** from start to finish.

# %% [markdown]
# ## Import All 13 Domain Classes
#
# ### What we're about to do
# We'll import every domain class that Spindle provides. Each domain is a self-contained schema definition — think of it as a blueprint for an entire database.
#
# ### Why this matters
# Having all domains in one place lets you compare them, pick the right one for your use case, or combine ideas from multiple domains into a custom schema.
#
# ### What to expect
# A confirmation that all 13 domain classes loaded successfully.

# %%
from sqllocks_spindle import (
    RetailDomain,
    HealthcareDomain,
    FinancialDomain,
    SupplyChainDomain,
    IoTDomain,
    HrDomain,
    InsuranceDomain,
    MarketingDomain,
    EducationDomain,
    RealEstateDomain,
    ManufacturingDomain,
    TelecomDomain,
)

print("All 13 domain classes imported successfully!")
# Out:
# All 13 domain classes imported successfully!

# %% [markdown]
# ## List All Domains
#
# ### What we're about to do
# We'll loop over all 13 domains, instantiate each one, call `get_schema()`, and print a summary table showing:
# - **Domain name** — the human-readable label
# - **Description** — what business area it models
# - **Table count** — how many tables are in the schema
# - **Relationship count** — how many foreign-key relationships connect the tables
#
# ### Why this matters
# This gives you a bird's-eye view of everything Spindle offers out of the box. You can quickly find the domain that matches your project's needs without reading documentation page by page.
#
# ### What to expect
# A formatted table with one row per domain, showing name, description, tables, and relationships.

# %%
domains = [
    RetailDomain(),
    HealthcareDomain(),
    FinancialDomain(),
    SupplyChainDomain(),
    IoTDomain(),
    HrDomain(),
    InsuranceDomain(),
    MarketingDomain(),
    EducationDomain(),
    RealEstateDomain(),
    ManufacturingDomain(),
    TelecomDomain(),
]

print(f"{'Domain':<22} {'Description':<45} {'Tables':>6} {'FKs':>6}")
print("-" * 82)

for domain in domains:
    schema = domain.get_schema()
    print(
        f"{schema.model.name:<22} "
        f"{schema.model.description[:43]:<45} "
        f"{len(schema.tables):>6} "
        f"{len(schema.relationships):>6}"
    )

print(f"\nTotal domains: {len(domains)}")
# Out:
# Domain                 Description                                   Tables    FKs
# ----------------------------------------------------------------------------------
# retail_3nf             Retail domain — 3nf schema                         9      9
# healthcare_3nf         Healthcare domain — 3nf schema                     9     10
# financial_3nf          Financial services domain — 3nf schema            10      9
# supply_chain_3nf       Supply chain domain — 3nf schema                  10     10
# iot_3nf                IoT domain — 3nf schema                            8      7
# hr_3nf                 Human resources domain — 3nf schema                9      8
# insurance_3nf          Insurance domain — 3nf schema                      9      8
# marketing_3nf          Marketing domain — 3nf schema                     10     11
# education_3nf          Education domain — 3nf schema                      9     11
# real_estate_3nf        Real estate domain — 3nf schema                    9     11
# manufacturing_3nf      Manufacturing domain — 3nf schema                  9      8
# telecom_3nf            Telecom domain — 3nf schema                        9      8
#
# Total domains: 12

# %% [markdown]
# ## Deep Describe: Retail Domain
#
# ### What we're about to do
# We'll take the Retail domain and print its complete internal structure:
# - Every table name and its column count
# - The table names in the schema
#
# ### Why this matters
# Understanding a domain's table structure reveals its scope. You can see at a glance which entities the domain models and how many columns each table defines.
#
# ### What to expect
# A list of tables with column counts, followed by the full list of table names.

# %%
retail = RetailDomain()
schema = retail.get_schema()

print(f"Domain: {schema.model.name}")
print(f"Description: {schema.model.description}")
print(f"\n=== Tables ({len(schema.tables)}) ===")
for table_name, table_def in schema.tables.items():
    col_count = len(table_def.columns)
    print(f"  {table_name:<30} {col_count:>3} columns")

print(f"\n=== Table Names ===")
for i, table_name in enumerate(schema.table_names, 1):
    print(f"  {i}. {table_name}")
# Out:
# Domain: retail_3nf
# Description: Retail domain — 3nf schema
#
# === Tables (9) ===
#   customer                         8 columns
#   address                         10 columns
#   product_category                 4 columns
#   product                          6 columns
#   store                            5 columns
#   promotion                        6 columns
#   order                            8 columns
#   order_line                       8 columns
#   return                           5 columns
#
# === Table Names ===
#   1. customer
#   2. address
#   3. product_category
#   4. product
#   5. store
#   6. promotion
#   7. order
#   8. order_line
#   9. return

# %% [markdown]
# ## Generate and Compare Two Domains Side-by-Side
#
# ### What we're about to do
# We'll generate both the **Retail** and **Healthcare** domains at the `fabric_demo` scale, then compare:
# - Their summaries (table names and row counts)
# - How long each took to generate
#
# ### Why this matters
# Different domains have different complexities — more tables, more relationships, more columns. This comparison helps you understand the performance characteristics and choose appropriate scales for your use case.
#
# ### What to expect
# Two summary blocks (one per domain) followed by a timing comparison.

# %%
import time
from sqllocks_spindle import Spindle

spindle = Spindle()

# Generate Retail
t0 = time.perf_counter()
retail_result = spindle.generate(
    domain=RetailDomain(), scale="fabric_demo", seed=42
)
retail_time = time.perf_counter() - t0

# Generate Healthcare
t0 = time.perf_counter()
healthcare_result = spindle.generate(
    domain=HealthcareDomain(), scale="fabric_demo", seed=42
)
healthcare_time = time.perf_counter() - t0

print("=== Retail Domain ===")
print(retail_result.summary())

print("\n=== Healthcare Domain ===")
print(healthcare_result.summary())

print("\n=== Timing Comparison ===")
print(f"  Retail:     {retail_time:.2f}s")
print(f"  Healthcare: {healthcare_time:.2f}s")
# Out:
# === Retail Domain ===
# Spindle Generation Result
# ========================================
# Schema: retail_3nf
# Domain: retail
# Mode:   3nf
# Seed:   42
# Time:   0.3s
#
# Table                             Rows  Columns
# ---------------------------------------------
# customer                           200        8
# address                            300       10
# product_category                    50        4
# product                            100        6
# promotion                          200        6
# store                              150        5
# order                            1,000        8
# order_line                       2,500        8
# return                             170        5
# ---------------------------------------------
# TOTAL                            4,670
#
# === Healthcare Domain ===
# Spindle Generation Result
# ========================================
# Schema: healthcare_3nf
# Domain: healthcare
# Mode:   3nf
# Seed:   42
# Time:   0.0s
#
# Table                             Rows  Columns
# ---------------------------------------------
# facility                            50       11
# patient                            100       17
# provider                            20        7
# encounter                          500        7
# claim                              475       10
# diagnosis                          900        6
# medication                         450        7
# procedure                          600        7
# claim_line                       1,187        8
# ---------------------------------------------
# TOTAL                            4,282
#
# === Timing Comparison ===
#   Retail:     0.26s
#   Healthcare: 0.05s

# %% [markdown]
# ## What's Next?
#
# You've now seen all 13 domains Spindle offers, explored one in detail, and compared generation across domains. Here's where to go from here:
#
# | Notebook | What You'll Learn |
# |----------|-------------------|
# | **T03: Custom Schema** | Define your own tables, columns, and relationships from scratch |
# | **T04: Healthcare Deep Dive** | Generate a full healthcare dataset, explore clinical tables, and build sample queries |
#
# Happy exploring!
